# %% [markdown]
# Download necessary libraries

# %%
import folium
import pandas as pd
from branca.colormap import LinearColormap

# %% [markdown]
# Create data frame from location and production data

# %%
# Load the data from the Excel file
df = pd.read_excel('Location.xlsx')

# Convert 'Acai' and 'Brazil nut' columns to numeric type
df['Acai'] = pd.to_numeric(df['Acai'], errors='coerce')
df['Brazil nut'] = pd.to_numeric(df['Brazil nut'], errors='coerce')
print(df)
# Out:
#                         City   Latitude  Longitude Indicator   Acai  Brazil nut
# 0                Porto Velho  -8.749453 -63.873543     Found   97.0      1200.0
# 1                Nova Mamoré -10.410486 -65.331375     Found  110.0        55.0
# 2                    Buritis -10.205494 -63.828194     Found  630.0         NaN
# 3         Candeias do Jamari  -8.794994 -63.701885     Found    3.0         2.0
# 4              Costa Marques -12.436716 -64.227974     Found   51.0        38.0
# ..                       ...        ...        ...       ...    ...         ...
# 342                    Juara -11.253559 -57.508007     Found    NaN        27.0
# 343  Novo Horizonte do Norte -11.390402 -57.315907     Found    NaN         1.0
# 344                 Tabaporã -11.308529 -56.821274     Found    NaN         2.0
# 345                   Itaúba -10.333333 -53.200001     Found    NaN       200.0
# 346        Nova Santa Helena -10.849536 -55.178043     Found    NaN        12.0
#
# [347 rows x 6 columns]

# %% [markdown]
# create a blank map and zoom toward America

# %%
# Create a colormap for Acai values
acai_colormap = LinearColormap(['green', 'yellow', 'red'], vmin=df['Acai'].min(), vmax=df['Acai'].max())

# Create a map centered around Brazil for Acai
m_acai = folium.Map(location=[-14.235, -51.9253], zoom_start=4)
display(m_acai)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9bab55f60b9a6e959538407e0ff75bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9bab55f60b9a6e959538407e0ff75bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9bab55f60b9a6e959538407e0ff75bb = L.map(
#                 &quot;map_a9bab55f60b9a6e959538407e0ff75bb&quot;,
#                 {
#                     center: [-14.235, -51.9253],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acfca6e0074ad7c8b52f9adb7ed32d37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_acfca6e0074ad7c8b52f9adb7ed32d37.addTo(map_a9bab55f60b9a6e959538407e0ff75bb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Adding the production site data with colour scaled markers

# %%
# Add markers for each city with Acai values
for i, row in df.iterrows():
    # If latitude and longitude are available, and Acai value is not null, add a marker
    if pd.notnull(row['Latitude']) and pd.notnull(row['Longitude']) and pd.notnull(row['Acai']):
        folium.CircleMarker(
            location=[row['Latitude'], row['Longitude']],
            radius=5,
            popup=f"Town: {row['City']}<br>Acai: {row['Acai']}",
            fill=True,
            color=acai_colormap(row['Acai']),
            fill_opacity=0.7
        ).add_to(m_acai)
display(m_acai)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfbb259802323a180a94b5c7a8b026ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfbb259802323a180a94b5c7a8b026ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfbb259802323a180a94b5c7a8b026ed = L.map(
#                 &quot;map_dfbb259802323a180a94b5c7a8b026ed&quot;,
#                 {
#                     center: [-14.235, -51.9253],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_914d9bdc7eb8c953f2367a7082f7ced2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_914d9bdc7eb8c953f2367a7082f7ced2.addTo(map_dfbb259802323a180a94b5c7a8b026ed);
#
#
#             tile_layer_914d9bdc7eb8c953f2367a7082f7ced2.addTo(map_dfbb259802323a180a94b5c7a8b026ed);
#
#
#             var circle_marker_7ab601d379c9a913b2cb29df61a5fbeb = L.circleMarker(
#                 [-8.74945259, -63.87354279],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#018100ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#018100ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dfbb259802323a180a94b5c7a8b026ed);
#
#
#         var popup_56eafd4ad4fd374ca10e02bf190716ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2d79975c325033b7b10d89ffd22d85e = $(`&lt;div id=&quot;html_f2d79975c325033b7b10d89ffd22d85e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town: Porto Velho&lt;br&gt;Acai: 97.0&lt;/div&gt;`)[0];
#                 popup_56eafd4ad4fd374ca10e02bf190716ae.setContent(html_f2d79975c325033b7b10d89ffd22d85e);
#
#
#
#         circle_marker_7ab601d379c9a913b2cb29df61a5fbeb.bindPopup(popup_56eafd4ad4fd374ca10e02bf190716ae)
#         ;
#
#
#
#
#             var circle_marker_3153a79acfb195d632b73f684285999b = L.circleMarker(
#                 [-10.41048622, -65.33137512],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#018100ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#018100ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dfbb259802323a180a94b5c7a8b026ed);
#
#
#         var popup_742b9cc4a82bdf5273848d6a57cc3a7e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db64dcb6d9f5af9dc7f30f27d2412533 = $(`&lt;div id=&quot;html_db64dcb6d9f5af9dc7f30f27d2412533&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town: Nova Mamoré&lt;br&gt;Acai: 110.0&lt;/div&gt;`)[0];
#                 popup_742b9cc4a82bdf5273848d6a57cc3a7e.setContent(html_db64dcb6d9f5af9dc7f30f27d2412533);
#
#
#
#         circle_marker_3153a79acfb195d632b73f684285999b.bindPopup(popup_742b9cc4a82bdf5273848d6a57cc3a7e)
#         ;
#
#
#
#
#             var circle_marker_97d552a0d1cc62548d1e151d48678650 = L.circleMarker(
#                 [-10.20549393, -63.82819366],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#098500ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#098500ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dfbb259802323a180a94b5c7a8b026ed);
#
#
#         var popup_fe90c2891e16387c50e8191a737ae59b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b7a0252de3e124e8ec3d43ef79d82776 = $(`&lt;div id=&quot;html_b7a0252de3e124e8ec3d43ef79d82776&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town: Buritis&lt;br&gt;Acai: 630.0&lt;/div&gt;`)[0];
#                 popup_fe90c2891e16387c50e8191a737ae59b.setContent(html_b7a0252de3e124e8ec3d43ef79d82776);
#
#
#
#         circle_marker_97d552a0d1cc62548d1e151d48678650.bindPopup(popup_fe90c2891e16387c50e8191a737ae59b)
#         ;
#
#
#
#
#             var circle_marker_6958f436b9c9398e27aa10e5dd9e2fd7 = L.circleMarker(
#                 [-8.79499435, -63.70188522],

# %% [markdown]
# Adding the scale bar

# %%
# Add the colormap to the map
acai_colormap.add_to(m_acai)
display(m_acai)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfbb259802323a180a94b5c7a8b026ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfbb259802323a180a94b5c7a8b026ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfbb259802323a180a94b5c7a8b026ed = L.map(
#                 &quot;map_dfbb259802323a180a94b5c7a8b026ed&quot;,
#                 {
#                     center: [-14.235, -51.9253],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_914d9bdc7eb8c953f2367a7082f7ced2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_914d9bdc7eb8c953f2367a7082f7ced2.addTo(map_dfbb259802323a180a94b5c7a8b026ed);
#
#
#             tile_layer_914d9bdc7eb8c953f2367a7082f7ced2.addTo(map_dfbb259802323a180a94b5c7a8b026ed);
#
#
#             var circle_marker_7ab601d379c9a913b2cb29df61a5fbeb = L.circleMarker(
#                 [-8.74945259, -63.87354279],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#018100ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#018100ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dfbb259802323a180a94b5c7a8b026ed);
#
#
#         var popup_56eafd4ad4fd374ca10e02bf190716ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2d79975c325033b7b10d89ffd22d85e = $(`&lt;div id=&quot;html_f2d79975c325033b7b10d89ffd22d85e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town: Porto Velho&lt;br&gt;Acai: 97.0&lt;/div&gt;`)[0];
#                 popup_56eafd4ad4fd374ca10e02bf190716ae.setContent(html_f2d79975c325033b7b10d89ffd22d85e);
#
#
#
#         circle_marker_7ab601d379c9a913b2cb29df61a5fbeb.bindPopup(popup_56eafd4ad4fd374ca10e02bf190716ae)
#         ;
#
#
#
#
#             var circle_marker_3153a79acfb195d632b73f684285999b = L.circleMarker(
#                 [-10.41048622, -65.33137512],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#018100ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#018100ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dfbb259802323a180a94b5c7a8b026ed);
#
#
#         var popup_742b9cc4a82bdf5273848d6a57cc3a7e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db64dcb6d9f5af9dc7f30f27d2412533 = $(`&lt;div id=&quot;html_db64dcb6d9f5af9dc7f30f27d2412533&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town: Nova Mamoré&lt;br&gt;Acai: 110.0&lt;/div&gt;`)[0];
#                 popup_742b9cc4a82bdf5273848d6a57cc3a7e.setContent(html_db64dcb6d9f5af9dc7f30f27d2412533);
#
#
#
#         circle_marker_3153a79acfb195d632b73f684285999b.bindPopup(popup_742b9cc4a82bdf5273848d6a57cc3a7e)
#         ;
#
#
#
#
#             var circle_marker_97d552a0d1cc62548d1e151d48678650 = L.circleMarker(
#                 [-10.20549393, -63.82819366],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#098500ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#098500ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dfbb259802323a180a94b5c7a8b026ed);
#
#
#         var popup_fe90c2891e16387c50e8191a737ae59b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b7a0252de3e124e8ec3d43ef79d82776 = $(`&lt;div id=&quot;html_b7a0252de3e124e8ec3d43ef79d82776&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town: Buritis&lt;br&gt;Acai: 630.0&lt;/div&gt;`)[0];
#                 popup_fe90c2891e16387c50e8191a737ae59b.setContent(html_b7a0252de3e124e8ec3d43ef79d82776);
#
#
#
#         circle_marker_97d552a0d1cc62548d1e151d48678650.bindPopup(popup_fe90c2891e16387c50e8191a737ae59b)
#         ;
#
#
#
#
#             var circle_marker_

# %% [markdown]
# Save to html

# %%
# Save the map as HTML file for Acai
m_acai.save('map_acai.html')
