# %% [markdown]
# Import neccesary libraries

# %%
import folium
import pandas as pd
from branca.colormap import LinearColormap

# %% [markdown]
# Load the location and production data

# %%
# Load the data from CSV
data = pd.read_excel('LocationForecast.xlsx')
print(data)
# Out:
#                         City   Latitude  ...  Unnamed: 51  Unnamed: 52
# 0                Porto Velho  -8.749453  ...          NaN          NaN
# 1                Nova Mamoré -10.410486  ...          NaN          NaN
# 2                    Buritis -10.205494  ...          NaN          NaN
# 3         Candeias do Jamari  -8.794994  ...          NaN          NaN
# 4              Costa Marques -12.436716  ...          NaN          NaN
# ..                       ...        ...  ...          ...          ...
# 342                    Juara -11.253559  ...          NaN          NaN
# 343  Novo Horizonte do Norte -11.390402  ...          NaN          NaN
# 344                 Tabaporã -11.308529  ...          NaN          NaN
# 345                   Itaúba -10.333333  ...          NaN          NaN
# 346        Nova Santa Helena -10.849536  ...          NaN      62092.0
#
# [347 rows x 53 columns]

# %% [markdown]
# Create 2 ranges of scale to improve noticibility as the map changes over the years

# %%
# Define the minimum and maximum values for the color scale
min_value = 1
max_value = 1200

# Define the number of colors in the colormap
num_colors = 10

# Create a logarithmic colormap
colors = ['lightgreen','yellow','orange', 'red']  # Define your colors here
acai_colormap = LinearColormap(colors=colors, vmin=min_value, vmax=max_value)
colors2 = ['red','darkred','black']
acai_colormap2 = LinearColormap(colors=colors2, vmin=1200, vmax=63000)
display(acai_colormap)
display(acai_colormap2)
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#90ee90ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#91ef8fff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#92ef8eff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#92ef8dff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#93ef8cff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#94ef8bff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#95ef8aff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#95ef89ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#96ef88ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#97ef87ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#98f086ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#98f085ff;stroke-width:2;" /><line x1="12" y1="15" x2="12" y2="27" style="stroke:#99f084ff;stroke-width:2;" /><line x1="13" y1="15" x2="13" y2="27" style="stroke:#9af084ff;stroke-width:2;" /><line x1="14" y1="15" x2="14" y2="27" style="stroke:#9af083ff;stroke-width:2;" /><line x1="15" y1="15" x2="15" y2="27" style="stroke:#9bf082ff;stroke-width:2;" /><line x1="16" y1="15"
0000ff;stroke-width:2;" /><line x1="32" y1="15" x2="32" y2="27" style="stroke:#ef0000ff;stroke-width:2;" /><line x1="33" y1="15" x2="33" y2="27" style="stroke:#ee0000ff;stroke-width:2;" /><line x1="34" y1="15" x2="34" y2="27" style="stroke:#ee0000ff;stroke-width:2;" /><line x1="35" y1="15" x2="35" y2="27" style="stroke:#ed0000ff;stroke-width:2;" /><line x1="36" y1="15" x2="36" y2="27" style="stroke:#ed0000ff;stroke-width:2;" /><line x1="37" y1="15" x2="37" y2="27" style="stroke:#ec0000ff;stroke-width:2;" /><line x1="38" y1="15" x2="38" y2="27" style="stroke:#ec0000ff;stroke-width:2;" /><line x1="39" y1="15" x2="39" y2="27" style="stroke:#eb0000ff;stroke-width:2;" /><line x1="40" y1="15" x2="40" y2="27" style="stroke:#eb0000ff;stroke-width:2;" /><line x1="41" y1="15" x2="41" y2="27" style="stroke:#ea0000ff;stroke-width:2;" /><line x1="42" y1="15" x2="42" y2="27" style="stroke:#ea0000ff;stroke-width:2;" /><line x1="43" y1="15" x2="43" y2="27" style="stroke:#e90000ff;stroke-width:2;" /><line x1="44" y1="15" x2="44" y2="27" style="stroke:#e90000ff;stroke-width:2;" /><line x1="45" y1="15" x2="45" y2="27" style="stroke:#e80000ff;stroke-width:2;" /><line x1="46" y1="15" x2="46" y2="27" style="stroke:#e80000ff;stroke-width:2;" /><line x1="47" y1="15" x2="47" y2="27" style="stroke:#e70000ff;stroke-width:2;" /><line x1="48" y1="15" x2="48" y2="27" style="stroke:#e70000ff;stroke-width:2;" /><line x1="49" y1="15"  ...

# %% [markdown]
# Creating the map from 2000-2050 with the exclusion of 2017-2019 due to lack of data

# %%
# Years to include (excluding 2017, 2018, 2019)
years = ["Year "+ str(i)  for i in range(2000, 2051) if i not in [2017, 2018, 2019]]
# Iterate over each year
for year in years:
    # Create a map
    m_acai = folium.Map(location=[-10, -58.9253], zoom_start=5)
    # Add markers to the map
    for _, row in data.iterrows():
        if pd.notnull(row['Latitude']) and pd.notnull(row['Longitude']):
            acai_value = row[year]
            if pd.notnull(acai_value) and acai_value > 0 and acai_value<1200:
                folium.CircleMarker(
                    location=[row['Latitude'], row['Longitude']],
                    radius=5,
                    popup=f"Town: {row['City']}<br>Acai: {acai_value}",
                    fill=True,
                    fill_color=acai_colormap(acai_value),
                    fill_opacity=0.8,
                    color='black',  # Outline color
                    weight=1 # Outline weight
                ).add_to(m_acai)
            elif pd.notnull(acai_value) and acai_value > 0 and acai_value>1200:
                 folium.CircleMarker(
                    location=[row['Latitude'], row['Longitude']],
                    radius=5,
                    popup=f"Town: {row['City']}<br>Acai: {acai_value}",
                    fill=True,
                    fill_color=acai_colormap2(acai_value),
                    fill_opacity=0.8,
                    color='black',  # Outline color
                    weight=1 # Outline weight
                ).add_to(m_acai)
    acai_colormap.add_to(m_acai)
    acai_colormap2.add_to(m_acai)
    
    # Add a title
    title_html = f'''
        <h3 align="center" style="font-size:20px"><b>Acai production in {year} (Tonnes)</b></h3>
    '''
    m_acai.get_root().html.add_child(folium.Element(title_html))

    # Save the map to an HTML file
    m_acai.save(f'map_acai_production_{year}.html')

# %%
display(m_acai)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c61c93d887a5c6ecad0910320286b16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#         &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;Acai production in Year 2050 (Tonnes)&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c61c93d887a5c6ecad0910320286b16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c61c93d887a5c6ecad0910320286b16 = L.map(
#                 &quot;map_1c61c93d887a5c6ecad0910320286b16&quot;,
#                 {
#                     center: [-10.0, -58.9253],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8f1ae9c5e13e1276730a20e4121fd96 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c8f1ae9c5e13e1276730a20e4121fd96.addTo(map_1c61c93d887a5c6ecad0910320286b16);
#
#
#             var circle_marker_6efbbfcb52eaafdc34cab9ffbb1ba3c7 = L.circleMarker(
#                 [-8.74945259, -63.87354279],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#bef554ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1c61c93d887a5c6ecad0910320286b16);
#
#
#         var popup_a21b530b11483f9582e8d0a3ae9888bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e93a513f8bb0a5a199d63805235949a = $(`&lt;div id=&quot;html_1e93a513f8bb0a5a199d63805235949a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town: Porto Velho&lt;br&gt;Acai: 166&lt;/div&gt;`)[0];
#                 popup_a21b530b11483f9582e8d0a3ae9888bf.setContent(html_1e93a513f8bb0a5a199d63805235949a);
#
#
#
#         circle_marker_6efbbfcb52eaafdc34cab9ffbb1ba3c7.bindPopup(popup_a21b530b11483f9582e8d0a3ae9888bf)
#         ;
#
#
#
#
#             var circle_marker_eda3b4542d973bfb67cf58ba8e10eb8b = L.circleMarker(
#                 [-10.41048622, -65.33137512],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c4f64cff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1c61c93d887a5c6ecad0910320286b16);
#
#
#         var popup_14eb6b30ed69e67f6b4a179709dbb011 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a293075f8a989ddb112241e83408a2bd = $(`&lt;div id=&quot;html_a293075f8a989ddb112241e83408a2bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town: Nova Mamoré&lt;br&gt;Acai: 189&lt;/div&gt;`)[0];
#                 popup_14eb6b30ed69e67f6b4a179709dbb011.setContent(html_a293075f8a989ddb112241e83408a2bd);
#
#
#
#         circle_marker_eda3b4542d973bfb67cf58ba8e10eb8b.bindPopup(popup_14eb6b30ed69e67f6b4a179709dbb011)
#         ;
#
#
#
#
#             var circle_marker_2a3a980a8b90acc86c733ace6313beca = L.circleMarker(
#                 [-10.20549393, -63.82819366],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff3100ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_1c61c93d887a5c6ecad0910320286b16);
#
#
#         var popup_89d9675c9caf54fbad5728e59fea4839 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82ad5b9f02a3b9d730ff415773dcfd7b = $(`&lt;div id=&quot;html_82ad5b9f02a3b9d730ff415773dcfd7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town: Buritis&lt;br&gt;Acai: 1080&lt;/div&gt;`)[0];
#                 popup_89d9675c9caf54fbad5728e59fea4839.setContent(html_82ad5b9f02a3b9d730ff415773dcfd7b);
#
#
#
#         circle_marker_2a3a980a8b90acc86c733ace6313beca.bindPopup(popup_89d9675c9caf54fbad5728e59fea4839)
#         ;
