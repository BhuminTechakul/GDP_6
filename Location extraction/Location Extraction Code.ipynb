# %% [markdown]
# Defining all the cities in the Brazilian Amazon with Acai and Brazil nuts production in 2016

# %%
cities = ["Porto Velho", "Nova Mamoré", "Buritis", "Candeias do Jamari", "Costa Marques", "Guajará-Mirim",
    "São Francisco do Guaporé", "Cacaulândia", "Vale do Anari", "Jaru", "Ji-Paraná", "Ouro Preto do Oeste",
    "Presidente Médici", "Mirante da Serra", "Nova União", "Teixeirópolis", "Urupá", "Vale do Paraíso",
    "Nova Brasilândia D'Oeste", "São Miguel do Guaporé", "Seringueiras", "Alta Floresta D'Oeste", "Cacoal",
    "Espigão D'Oeste", "Castanheiras", "Chupinguaia", "Cabixi", "Pimenteiras do Oeste", "Cruzeiro do Sul",
    "Mâncio Lima", "Marechal Thaumaturgo", "Porto Walter", "Rodrigues Alves", "Feijó", "Jordão", "Tarauacá",
    "Manoel Urbano", "Santa Rosa do Purus", "Sena Madureira", "Acrelândia", "Bujari", "Capixaba", "Plácido de Castro",
    "Rio Branco", "Senador Guiomard", "Porto Acre", "Assis Brasil", "Brasiléia", "Epitaciolândia", "Xapuri",
    "Barcelos", "Novo Airão", "Santa Isabel do Rio Negro", "São Gabriel da Cachoeira", "Japurá", "Maraã", "Amaturá",
    "Atalaia do Norte", "Benjamin Constant", "Fonte Boa", "Jutaí", "Santo Antônio do Içá", "São Paulo de Olivença",
    "Tabatinga", "Tonantins", "Carauari", "Eirunepé", "Envira", "Guajará", "Ipixuna", "Itamarati", "Juruá",
    "Alvarães", "Tefé", "Uarini", "Anamã", "Anori", "Beruri", "Caapiranga", "Coari", "Codajás", "Autazes", "Careiro",
    "Iranduba", "Manacapuru", "Manaquiri", "Manaus", "Presidente Figueiredo", "Rio Preto da Eva", "Itacoatiara",
    "Itapiranga", "Nova Olinda do Norte", "Silves", "Urucurituba", "Barreirinha", "Boa Vista do Ramos", "Maués",
    "Nhamundá", "Parintins", "São Sebastião do Uatumã", "Urucará", "Boca do Acre", "Pauini", "Canutama", "Lábrea",
    "Tapauá", "Apuí", "Borba", "Humaitá", "Manicoré", "Novo Aripuanã", "Caracaraí", "Caroebe", "Rorainópolis",
    "São João da Baliza", "São Luiz", "Faro", "Juruti", "Óbidos", "Oriximiná", "Terra Santa", "Alenquer", "Belterra",
    "Curuá", "Mojuí dos Campos", "Monte Alegre", "Placas", "Prainha", "Santarém", "Almeirim", "Bagre", "Gurupá",
    "Melgaço", "Portel", "Afuá", "Anajás", "Breves", "Curralinho", "São Sebastião da Boa Vista", "Cachoeira do Arari",
    "Chaves", "Muaná", "Ponta de Pedras", "Santa Cruz do Arari", "Ananindeua", "Barcarena", "Belém", "Benevides",
    "Marituba", "Santa Bárbara do Pará", "Bujaru", "Inhangapi", "Santa Isabel do Pará", "Santo Antônio do Tauá",
    "Colares", "Curuçá", "Magalhães Barata", "Maracanã", "Marapanim", "Salinópolis", "São Caetano de Odivelas",
    "São João da Ponta", "São João de Pirabas", "Terra Alta", "Vigia", "Augusto Corrêa", "Bonito", "Bragança",
    "Capanema", "Igarapé-Açu", "Nova Timboteua", "Peixe-Boi", "Primavera", "Quatipuru", "Santa Maria do Pará",
    "Santarém Novo", "São Francisco do Pará", "Tracuateua", "Abaetetuba", "Baião", "Cametá", "Igarapé-Miri",
    "Limoeiro do Ajuru", "Mocajuba", "Oeiras do Pará", "Acará", "Moju", "Tailândia", "Tomé-Açu", "Cachoeira do Piriá",
    "Capitão Poço", "Garrafão do Norte", "Irituia", "Nova Esperança do Piriá", "Ourém", "Santa Luzia do Pará",
    "São Domingos do Capim", "São Miguel do Guamá", "Viseu", "Aveiro", "Itaituba", "Jacareacanga", "Novo Progresso",
    "Rurópolis", "Trairão", "Altamira", "Anapu", "Brasil Novo", "Medicilândia", "Pacajá", "Senador José Porfírio",
    "Uruará", "Vitória do Xingu", "Breu Branco", "Itupiranga", "Jacundá", "Nova Ipixuna", "Novo Repartimento",
    "Tucuruí", "Bom Jesus do Tocantins", "Goianésia do Pará", "Bannach", "Cumaru do Norte", "Ourilândia do Norte",
    "São Félix do Xingu", "Água Azul do Norte", "Canaã dos Carajás", "Curionópolis", "Eldorado dos Carajás",
    "Parauapebas", "Brejo Grande do Araguaia", "Marabá", "São Domingos do Araguaia", "São João do Araguaia",
    "Piçarra", "São Geraldo do Araguaia", "Xinguara", "Calçoene", "Oiapoque", "Amapá", "Pracuúba", "Tartarugalzinho", "Serra do Navio",
    "Pedra Branca do Amapari", "Cutias", "Ferreira Gomes", "Itaubal", "Macapá", "Porto Grande", "Santana",
    "Laranjal do Jari", "Mazagão", "Vitória do Jari", "Alcântara", "Apicum-Açu", "Bacuri", "Cedral",
    "Central do Maranhão", "Cururupu", "Guimarães", "Mirinzal", "Porto Rico do Maranhão", "Serrano do Maranhão",
    "Paço do Lumiar", "São José de Ribamar", "São Luís", "Axixá", "Bacabeira", "Cachoeira Grande", "Icatu",
    "Morros", "Presidente Juscelino", "Rosário", "Santa Rita", "Barreirinhas", "Humberto de Campos",
    "Primeira Cruz", "Santo Amaro do Maranhão", "Anajatuba", "Arari", "Bela Vista do Maranhão", "Cajari",
    "Igarapé do Meio", "Matinha", "Monção", "Olinda Nova do Maranhão", "Palmeirândia", "Pedro do Rosário",
    "Penalva", "Peri Mirim", "Pinheiro", "Presidente Sarney", "Santa Helena", "São Bento", "São João Batista",
    "São Vicente Ferrer", "Viana", "Vitória do Mearim", "Itapecuru Mirim", "Amapá do Maranhão",
    "Boa Vista do Gurupi", "Cândido Mendes", "Carutapera", "Centro do Guilherme", "Centro Novo do Maranhão",
    "Godofredo Viana", "Governador Nunes Freire", "Junco do Maranhão", "Luís Domingues", "Maracaçumé",
    "Maranhãozinho", "Turiaçu", "Alto Alegre do Pindaré", "Araguanã", "Governador Newton Bello",
    "Nova Olinda do Maranhão", "Pindaré-Mirim", "Presidente Médici", "Santa Inês", "Santa Luzia do Paruá",
    "São João do Carú", "Tufilândia", "Amarante do Maranhão", "Cidelândia", "Imperatriz",
    "São Pedro da Água Branca", "Vila Nova dos Martírios", "Aripuanã", "Brasnorte", "Castanheira",
    "Colniza", "Cotriguaçu", "Juína", "Juruena", "Rondolândia", "Alta Floresta", "Apiacás",
    "Nova Bandeirantes", "Paranaíta", "Nova Monte Verde", "Guarantã do Norte", "Terra Nova do Norte",
    "Juara", "Novo Horizonte do Norte", "Tabaporã", "Itaúba", "Nova Santa Helena",
]

# %% [markdown]
# Import necessary libraries

# %%
# !pip install geocoder

import geocoder
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geocoder in /home/repl/.local/lib/python3.10/site-packages (1.38.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from geocoder) (8.1.7)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from geocoder) (1.0.0)
# Requirement already satisfied: ratelim in /home/repl/.local/lib/python3.10/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from geocoder) (2.31.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from geocoder) (1.16.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ratelim->geocoder) (5.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder) (2024.2.2)

# %%
# Initialize lists to store city names, latitudes, longitudes, and indicators
city_names = []
latitudes = []
longitudes = []
indicators = []
states = ["Rondônia","Acre","Amazonas","Roraima","Pará","Amapá","Maranhão", "Mato Grosso"]
states_now = "Rondônia"
# Loop through each city in the list
for city in cities:
    # Retrieve geolocation data for the city
    if city == "Cruzeiro do Sul":
      states_now = "Acre"
    elif city == "Barcelos":
      states_now = "Amazonas"
    elif city == "Normandia":
      states_now = "Roraima"
    elif city == "Faro":
      states_now = "Pará"
    elif city == "Calçoene":
      states_now = "Amapá"
    elif city == "Alcântara":
      states_now = "Maranhão"
    elif city == "Aripuanã":
      states_now = "Mato Gross"
      
    print(str(city)+" " + str(states_now))
    g = geocoder.bing(str(city)+ ", " + str(states_now)+ ", Brazil", key='DinjjAI58J0b7ycvFn7r~89PMoU-ZMiY-JA9mp6H2xw~AlCLNL-F_uprGVLwRL-_Hkw9yy2RUDN_ZeY0m8rvPeFGbBVrXLTbMUZfEIS3NKlv')
    
    # Check if the response is valid
    if g is not None:
        # Extract latitude and longitude from the geolocation result
        lat = g.json['lat']
        lng = g.json['lng']
        
        # Append city name, latitude, and longitude to respective lists
        city_names.append(city)
        latitudes.append(lat)
        longitudes.append(lng)
        indicators.append("Found")
    else:
        # If the response is None, mark the city as not found
        city_names.append(city)
        latitudes.append(None)
        longitudes.append(None)
        indicators.append("Not Found")
# Out:
# Porto Velho Rondônia
# Nova Mamoré Rondônia
# Buritis Rondônia
# Candeias do Jamari Rondônia
# Costa Marques Rondônia
# Guajará-Mirim Rondônia
# São Francisco do Guaporé Rondônia
# Cacaulândia Rondônia
# Vale do Anari Rondônia
# Jaru Rondônia
# Ji-Paraná Rondônia
# Ouro Preto do Oeste Rondônia
# Presidente Médici Rondônia
# Mirante da Serra Rondônia
# Nova União Rondônia
# Teixeirópolis Rondônia
# Urupá Rondônia
# Vale do Paraíso Rondônia
# Nova Brasilândia D'Oeste Rondônia
# São Miguel do Guaporé Rondônia
# Seringueiras Rondônia
# Alta Floresta D'Oeste Rondônia
# Cacoal Rondônia
# Espigão D'Oeste Rondônia
# Castanheiras Rondônia
# Chupinguaia Rondônia
# Cabixi Rondônia
# Pimenteiras do Oeste Rondônia
# Cruzeiro do Sul Acre
# Mâncio Lima Acre
# Marechal Thaumaturgo Acre
# Porto Walter Acre
# Rodrigues Alves Acre
# Feijó Acre
# Jordão Acre
# Tarauacá Acre
# Manoel Urbano Acre
# Santa Rosa do Purus Acre
# Sena Madureira Acre
# Acrelândia Acre
# Bujari Acre
# Capixaba Acre
# Plácido de Castro Acre
# Rio Branco Acre
# Senador Guiomard Acre
# Porto Acre Acre
# Assis Brasil Acre
# Brasiléia Acre
# Epitaciolândia Acre
# Xapuri Acre
# Barcelos Amazonas
# Novo Airão Amazonas
# Santa Isabel do Rio Negro Amazonas
# São Gabriel da Cachoeira Amazonas
# Japurá Amazonas
# Maraã Amazonas
# Amaturá Amazonas
# Atalaia do Norte Amazonas
# Benjamin Constant Amazonas
# Fonte Boa Amazonas
# Jutaí Amazonas
# Santo Antônio do Içá Amazonas
# São Paulo de Olivença Amazonas
# Tabatinga Amazonas
# Tonantins Amazonas
# Carauari Amazonas
# Eirunepé Amazonas
# Envira Amazonas
# Guajará Amazonas
# Ipixuna Amazonas
# Itamarati Amazonas
# Juruá Amazonas
# Alvarães Amazonas
# Tefé Amazonas
# Uarini Amazonas
# Anamã Amazonas
# Anori Amazonas
# Beruri Amazonas
# Caapiranga Amazonas
# Coari Amazonas
# Codajás Amazonas
# Autazes Amazonas
# Careiro Amazonas
# Iranduba Amazonas
# Manacapuru Amazonas
# Manaquiri Amazonas
# Manaus Amazonas
# Presidente Figueiredo Amazonas
# Rio Preto da Eva Amazonas
# Itacoatiara Amazonas
# Itapiranga Amazonas
# Nova Olinda do Norte Amazonas
# Silves Amazonas
# Urucurituba Amazonas
# Barreirinha Amazonas
# Boa Vista do Ramos Amazonas
# Maués Amazonas
# Nhamundá Amazonas
# Parintins Amazonas
# São Sebastião do Uatumã Amazonas
# Urucará Amazonas
# Boca do Acre Amazonas
# Pauini Amazonas
# Canutama Amazonas
# Lábrea Amazonas
# Tapauá Amazonas
# Apuí Amazonas
# Borba Amazonas
# Humaitá Amazonas
# Manicoré Amazonas
# Novo Aripuanã Amazonas
# Caracaraí Amazonas
# Caroebe Amazonas
# Rorainópolis Amazonas
# São João da Baliza Amazonas
# São Luiz Amazonas
# Faro Pará
# Juruti Pará
# Óbidos Pará
# Oriximiná Pará
# Terra Santa Pará
# Alenquer Pará
# Belterra Pará
# Curuá Pará
# Mojuí dos Campos Pará
# Monte Alegre Pará
# Placas Pará
# Prainha Pará
# Santarém Pará
# Almeirim Pará
# Bagre Pará
# Gurupá Pará
# Melgaço Pará
# Portel Pará
# Afuá Pará
# Anajás Pará
# Breves Pará
# Curralinho Pará
# São Sebastião da Boa Vista Pará
# Cachoeira do Arari Pará
# Chaves Pará
# Muaná Pará
# Ponta de Pedras Pará
# Santa Cruz do Arari Pará
# Ananindeua Pará
# Barcarena Pará
# Belém Pará
# Benevides Pará
# Marituba Pará
# Santa Bárbara do Pará Pará
# Bujaru Pará
# Inhangapi Pará
# Santa Isabel do Pará Pará
# Santo Antônio do Tauá Pará
# Colares Pará
# Curuçá Pará
# Magalhães Barata Pará
# Maracanã Pará
# Marapanim Pará
# Salinópolis Pará
# São Caetano de Odivelas Pará
# São João da Ponta Pará
# São João de Pirabas Pará
# Terra Alta Pará
# Vigia Pará
# Augusto Corrêa Pará
# Bonito Pará
# Bragança Pará
# Capanema Pará
# Igarapé-Açu Pará
# Nova Timboteua Pará
# Peixe-Boi Pará
# Primavera Pará
# Quatipuru Pará
# Santa Maria do Pará Pará
# Santarém Novo Pará
# São Francisco do Pará Pará
# Tracuateua Pará
# Abaetetuba Pará
# Baião Pará
# Cametá Pará
# Igarapé-Miri Pará
# Limoeiro do Ajuru Pará
# Mocajuba Pará
# Oeiras do Pará Pará
# Acará Pará
# Moju Pará
# Tailândia Pará
# Tomé-Açu Pará
# Cachoeira do Piriá Pará
# Capitão Poço Pará
# Garrafão do Norte Pará
# Irituia Pará
# Nova Esperança do Piriá Pará
# Ourém Pará
# Santa Luzia do Pará Pará
# São Domingos do Capim Pará
# São Miguel do Guamá Pará
# Viseu Pará
# Aveiro Pará
# Itaituba Pará
# Jacareacanga Pará
# Novo Progresso Pará
# Rurópolis Pará
# Trairão Pará
# Altamira Pará
# Anapu Pará
# Brasil Novo Pará
# Medicilândia Pará
# Pacajá Pará
# Senador José Porfírio Pará
# Uruará Pará
# Vitória do Xingu Pará
# Breu Branco Pará
# Itupiranga Pará
# Jacundá Pará
# Nova Ipixuna Pará
# Novo Repartimento Pará
# Tucuruí Pará
# Bom Jesus do Tocantins Pará
# Goianésia do Pará Pará
# Bannach Pará
# Cumaru do Norte Pará
# Ourilândia do Norte Pará
# São Félix do Xingu Pará
# Água Azul do Norte Pará
# Canaã dos Carajás Pará
# Curionópolis Pará
# Eldorado dos Carajás Pará
# Parauapebas Pará
# Brejo Grande do Araguaia Pará
# Marabá Pará
# São Domingos do Araguaia Pará
# São João do Araguaia Pará
# Piçarra Pará
# São Geraldo do Araguaia Pará
# Xinguara Pará
# Calçoene Amapá
# Oiapoque Amapá
# Amapá Amapá
# Pracuúba Amapá
# Tartarugalzinho Amapá
# Serra do Navio Amapá
# Pedra Branca do Amapari Amapá
# Cutias Amapá
# Ferreira Gomes Amapá
# Itaubal Amapá
# Macapá Amapá
# Porto Grande Amapá
# Santana Amapá
# Laranjal do Jari Amapá
# Mazagão Amapá
# Vitória do Jari Amapá
# Alcântara Maranhão
# Apicum-Açu Maranhão
# Bacuri Maranhão
# Cedral Maranhão
# Central do Maranhão Maranhão
# Cururupu Maranhão
# Guimarães Maranhão
# Mirinzal Maranhão
# Porto Rico do Maranhão Maranhão
# Serrano do Maranhão Maranhão
# Paço do Lumiar Maranhão
# São José de Ribamar Maranhão
# São Luís Maranhão
# Axixá Maranhão
# Bacabeira Maranhão
# Cachoeira Grande Maranhão
# Icatu Maranhão
# Morros Maranhão
# Presidente Juscelino Maranhão
# Rosário Maranhão
# Santa Rita Maranhão
# Barreirinhas Maranhão
# Humberto de Campos Maranhão
# Primeira Cruz Maranhão
# Santo Amaro do Maranhão Maranhão
# Anajatuba Maranhão
# Arari Maranhão
# Bela Vista do Maranhão Maranhão
# Cajari Maranhão
# Igarapé do Meio Maranhão
# Matinha Maranhão
# Monção Maranhão
# Olinda Nova do Maranhão Maranhão
# Palmeirândia Maranhão
# Pedro do Rosário Maranhão
# Penalva Maranhão
# Peri Mirim Maranhão
# Pinheiro Maranhão
# Presidente Sarney Maranhão
# Santa Helena Maranhão
# São Bento Maranhão
# São João Batista Maranhão
# São Vicente Ferrer Maranhão
# Viana Maranhão
# Vitória do Mearim Maranhão
# Itapecuru Mirim Maranhão
# Amapá do Maranhão Maranhão
# Boa Vista do Gurupi Maranhão
# Cândido Mendes Maranhão
# Carutapera Maranhão
# Centro do Guilherme Maranhão
# Centro Novo do Maranhão Maranhão
# Godofredo Viana Maranhão
# Governador Nunes Freire Maranhão
# Junco do Maranhão Maranhão
# Luís Domingues Maranhão
# Maracaçumé Maranhão
# Maranhãozinho Maranhão
# Turiaçu Maranhão
# Alto Alegre do Pindaré Maranhão
# Araguanã Maranhão
# Governador Newton Bello Maranhão
# Nova Olinda do Maranhão Maranhão
# Pindaré-Mirim Maranhão
# Presidente Médici Maranhão
# Santa Inês Maranhão
# Santa Luzia do Paruá Maranhão
# São João do Carú Maranhão
# Tufilândia Maranhão
# Amarante do Maranhão Maranhão
# Cidelândia Maranhão
# Imperatriz Maranhão
# São Pedro da Água Branca Maranhão
# Vila Nova dos Martírios Maranhão
# Aripuanã Mato Gross
# Brasnorte Mato Gross
# Castanheira Mato Gross
# Colniza Mato Gross
# Cotriguaçu Mato Gross
# Juína Mato Gross
# Juruena Mato Gross
# Rondolândia Mato Gross
# Alta Floresta Mato Gross
# Apiacás Mato Gross
# Nova Bandeirantes Mato Gross
# Paranaíta Mato Gross
# Nova Monte Verde Mato Gross
# Guarantã do Norte Mato Gross
# Terra Nova do Norte Mato Gross
# Juara Mato Gross
# Novo Horizonte do Norte Mato Gross
# Tabaporã Mato Gross
# Itaúba Mato Gross
# Nova Santa Helena Mato Gross

# %%
# Create a DataFrame using pandas
df = pd.DataFrame({
    'City': city_names,
    'Latitude': latitudes,
    'Longitude': longitudes,
    'Indicator': indicators
})

# Export the DataFrame to an Excel file
df.to_excel('Location.xlsx', index=False)

# %%
print(df)
# Out:
#                         City   Latitude  Longitude Indicator
# 0                Porto Velho  -8.749453 -63.873543     Found
# 1                Nova Mamoré -10.410486 -65.331375     Found
# 2                    Buritis -10.205494 -63.828194     Found
# 3         Candeias do Jamari  -8.794994 -63.701885     Found
# 4              Costa Marques -12.436716 -64.227974     Found
# ..                       ...        ...        ...       ...
# 342                    Juara -11.253559 -57.508007     Found
# 343  Novo Horizonte do Norte -11.390402 -57.315907     Found
# 344                 Tabaporã -11.308529 -56.821274     Found
# 345                   Itaúba -10.333333 -53.200001     Found
# 346        Nova Santa Helena -10.849536 -55.178043     Found
#
# [347 rows x 4 columns]
