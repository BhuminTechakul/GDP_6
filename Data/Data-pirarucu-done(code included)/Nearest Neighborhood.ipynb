# %%
import pandas as pd
import re
from sklearn.neighbors import NearestNeighbors

# %%
from sklearn.cluster import KMeans

# %%
data = pd.read_excel('Location of pirarucu collection.xlsx')

data
# Out:
#                                                Name                  Type  \
# 0                                      Rio Solimões  Development Reserves
# 1                                         Rio Negro  Development Reserves
# 2                                         Rio Purus  Development Reserves
# 3                                         Rio Juruá  Development Reserves
# 4                                          Alvarães           City (town)
# 5                                             Anori           City (town)
# 6                                          Barcelos           City (town)
# 7                                            Beruri           City (town)
# 8                                          Carauari           City (town)
# 9                                         Fonte Boa           City (town)
# 10                                        Itamarati           City (town)
# 11                                           Japurá           City (town)
# 12                                            Juruá           City (town)
# 13                                            Jutaí           City (town)
# 14                                           Lábrea           City (town)
# 15                                            Maraã           City (town)
# 16                                       Novo Airão           City (town)
# 17                                           Tapauá           City (town)
# 18                                             Tefé           City (town)
# 19                                        Tonantins           City (town)
# 20                                           Uarini           City (town)
# 21                Reserva Extrativista Auati-Paraná   Extractive Reserves
# 22                 Reserva Extrativista Baixo Juruá   Extractive Reserves
# 23              Reserva Extrativista do Médio Juruá   Extractive Reserves
# 24              Reserva Extrativista do Médio Purús   Extractive Reserves
# 25                       Reserva Extrativista Ituxí   Extractive Reserves
# 26                Reserva Extrativista do Rio Jutaí   Extractive Reserves
# 27                   Reserva Extrativista Rio Unini   Extractive Reserves
# 28  Reserva de Desenvolvimento Sustentável Mamirauá  Development Reserves
# 29                      Terra Indígena Itixi Mitari      Indigenous Lands
# 30          Terra Indígena Paumari do Lago Manissuã      Indigenous Lands
# 31            Terra Indígena Paumari do Lago Paricá      Indigenous Lands
# 32                 Terra Indígena Paumari do Cuniuá      Indigenous Lands
# 33                              Terra Indígena Deni      Indigenous Lands
#
#    lng_coordinates lat_coordinates  Production (2022, tons)    Revenue
# 0        3°14'12"S      64°46'40"W                   102.94  105882.35
# 1        0°25'23"S      64°39'22"W                   102.94  105882.35
# 2        7°30'25"S      66°18'13"W                   102.94  105882.35
# 3        6°31'09"S      69°25'19"W                   102.94  105882.35
# 4        3°12'49"S      64°48'34"W                   123.59  125534.12
# 5        3°44'53"S      61°39'31"W                   123.59  125534.12
# 6        0°58'26"S      62°55'32"W                   123.59  125534.12
# 7        3°53'54"S      61°22'26"W                   123.59  125534.12
# 8        4°52'38"S      66°53'48"W                   123.59  125534.12
# 9        2°30'54"S      66°05'45"W                   123.59  125534.12
# 10       6°26'22"S      68°14'37"W                   123.59  125534.12
# 11       1°52'47"S      66°59'55"W                   123.59  125534.12
# 12       3°28'29"S      66°03'50"W                   123.59  125534.12
# 13       2°44'55"S      66°46'21"W                   123.59  125534.12
# 14       7°15'49"S      64°47'47"W                   123.59  125534.12
# 15       1°51'33"S      65°35'23"W                   123.59  125534.12
# 16       2°37'23"S      60°56'35"W                   123.59  125534.12
# 17       5°37'30"S      63°11'20"W                   123.59  125534.12
# 18       3°20'50"S      64°42'33"W                   123.59  125534.12
# 19       2°51'42"S      67°46'32"W                   123.59  125534.12
# 20       2°58'56"S      65°09'33"W                   123.59  125534.12
# 21       2°01'31"S      66°22'41"W                   102.94  105882.35
# 22       3°32'51"S      65°57'51"W                   102.94  105882.35
# 23       5°15'58"S      67°27'59"W                   102.94  105882.35
# 24       7°42'24"S      66°07'03"W                   102.94  105882.35
# 25       8°22'24"S      65°17'16"W                   102.94  105882.35
# 26       3°30'23"S      67°19'38"W                   102.94  105882.35
# 27       1°30'56"S      63°22'05"W                   102.94  105882.35
# 28       2°13'26"S      65°43'15"W                   102.94  105882.35
# 29       4°42'07"S      62°35'57"W                   102.94  105882.35
# 30       5°47'47"S      64°35'32"W                   102.94  105882.35
# 31       5°55'49"S      64°42'27"W                   102.94  105882.35
# 32       6°05'35"S      64°51'27"W                   102.94  105882.35
# 33       6°06'58"S      67°48'03"W                   102.94  105882.35

# %%
# Function to convert DMS to decimal degrees
def dms_to_decimal(dms):
    parts = re.split('[°\'"]', dms)
    degrees = float(parts[0])
    minutes = float(parts[1])
    seconds = float(parts[2][:-1]) if parts[2][-1] in 'NSEW' else float(parts[2])
    direction = parts[2][-1]
    
    decimal = degrees + minutes / 60 + seconds / 3600
    if direction in 'S'or'W':
        decimal = -decimal
    
    return decimal

# %%
# Convert coordinates to decimal
data['lng_decimal'] = data['lng_coordinates'].apply(dms_to_decimal)
data['lat_decimal'] = data['lat_coordinates'].apply(dms_to_decimal)

# %%
# Separate city (town) and non-city locations
cities = data[data['Type'] == 'City (town)']
non_city_types_corrected = ['Development Reserves', 'Extractive Reserves', 'Indigenous Lands']
non_cities_filtered_corrected = data[data['Type'].isin(non_city_types_corrected)]

# %%
# Extract coordinates
city_coords = cities[['lng_decimal', 'lat_decimal']].to_numpy()
non_city_coords_filtered_corrected = non_cities_filtered_corrected[['lng_decimal', 'lat_decimal']].to_numpy()

# %%
# Use Nearest Neighbors to find the closest city for each non-city location
nbrs = NearestNeighbors(n_neighbors=1, algorithm='ball_tree').fit(city_coords)
distances_filtered_corrected, indices_filtered_corrected = nbrs.kneighbors(non_city_coords_filtered_corrected)

# %%
# Assign the nearest city to each filtered non-city location
non_cities_filtered_corrected['Nearest_City'] = indices_filtered_corrected.flatten()
non_cities_filtered_corrected['Nearest_City_Name'] = non_cities_filtered_corrected['Nearest_City'].apply(lambda x: cities.iloc[x]['Name'])

non_cities_filtered_corrected[['Name', 'Type', 'Nearest_City_Name']]
# Out:
# C:\Users\ZHANG MAI\AppData\Local\Temp\ipykernel_9576\2537973057.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_cities_filtered_corrected['Nearest_City'] = indices_filtered_corrected.flatten()
# C:\Users\ZHANG MAI\AppData\Local\Temp\ipykernel_9576\2537973057.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_cities_filtered_corrected['Nearest_City_Name'] = non_cities_filtered_corrected['Nearest_City'].apply(lambda x: cities.iloc[x]['Name'])
#                                                Name                  Type  \
# 0                                      Rio Solimões  Development Reserves
# 1                                         Rio Negro  Development Reserves
# 2                                         Rio Purus  Development Reserves
# 3                                         Rio Juruá  Development Reserves
# 21                Reserva Extrativista Auati-Paraná   Extractive Reserves
# 22                 Reserva Extrativista Baixo Juruá   Extractive Reserves
# 23              Reserva Extrativista do Médio Juruá   Extractive Reserves
# 24              Reserva Extrativista do Médio Purús   Extractive Reserves
# 25                       Reserva Extrativista Ituxí   Extractive Reserves
# 26                Reserva Extrativista do Rio Jutaí   Extractive Reserves
# 27                   Reserva Extrativista Rio Unini   Extractive Reserves
# 28  Reserva de Desenvolvimento Sustentável Mamirauá  Development Reserves
# 29                      Terra Indígena Itixi Mitari      Indigenous Lands
# 30          Terra Indígena Paumari do Lago Manissuã      Indigenous Lands
# 31            Terra Indígena Paumari do Lago Paricá      Indigenous Lands
# 32                 Terra Indígena Paumari do Cuniuá      Indigenous Lands
# 33                              Terra Indígena Deni      Indigenous Lands
#
#    Nearest_City_Name
# 0           Alvarães
# 1              Maraã
# 2             Lábrea
# 3          Itamarati
# 21         Fonte Boa
# 22             Juruá
# 23          Carauari
# 24            Lábrea
# 25            Lábrea
# 26         Tonantins
# 27          Barcelos
# 28             Maraã
# 29            Tapauá
# 30            Tapauá
# 31            Lábrea
# 32            Lábrea
# 33         Itamarati

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\zhang mai\anaconda3\lib\site-packages (0.16.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\zhang mai\anaconda3\lib\site-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\zhang mai\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\zhang mai\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\zhang mai\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\zhang mai\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\zhang mai\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zhang mai\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zhang mai\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zhang mai\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zhang mai\anaconda3\lib\site-packages (from requests->folium) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
# Create a map object with the centre set to Brazil
mymap = folium.Map(location=[-3.4653, -62.2159], zoom_start=5)

# %%
# Mapping city nodes
for _, row in cities.iterrows():
    folium.CircleMarker(
        location=[row['lng_decimal'], row['lat_decimal']],
        radius=5,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"{row['Name']}",
    ).add_to(mymap)

# Mapping of non-city nodes and linkages
for _, row in non_cities_filtered_corrected.iterrows():
    folium.CircleMarker(
        location=[row['lng_decimal'], row['lat_decimal']],
        radius=5,
        color='red',
        fill=True,
        fill_color='red',
        popup=f"{row['Name']}",
    ).add_to(mymap)
    
    # the nearest city
    nearest_city_row = cities[cities['Name'] == row['Nearest_City_Name']].iloc[0]
    
    folium.PolyLine(
        locations=[
            [row['lng_decimal'], row['lat_decimal']],
            [nearest_city_row['lng_decimal'], nearest_city_row['lat_decimal']]
        ],
        color='black',
        weight=1
    ).add_to(mymap)

# %%
mymap.save("node_city_map_with_popup.html")  
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_664b6c010d0394f1a48592cdfb15675c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_664b6c010d0394f1a48592cdfb15675c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_664b6c010d0394f1a48592cdfb15675c = L.map(
#                 &quot;map_664b6c010d0394f1a48592cdfb15675c&quot;,
#                 {
#                     center: [-3.4653, -62.2159],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89e391805ede3f23114b8dbd26c85796 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_89e391805ede3f23114b8dbd26c85796.addTo(map_664b6c010d0394f1a48592cdfb15675c);
#
#
#             var circle_marker_881c483f9376c01376e212ae16df4363 = L.circleMarker(
#                 [-3.213611111111111, -64.80944444444444],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_664b6c010d0394f1a48592cdfb15675c);
#
#
#         var popup_3f5cd10cae7055be3110f3dca611f5ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd1d4b3859bc1ae902ef2d983aba2b9d = $(`&lt;div id=&quot;html_dd1d4b3859bc1ae902ef2d983aba2b9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alvarães&lt;/div&gt;`)[0];
#                 popup_3f5cd10cae7055be3110f3dca611f5ef.setContent(html_dd1d4b3859bc1ae902ef2d983aba2b9d);
#
#
#
#         circle_marker_881c483f9376c01376e212ae16df4363.bindPopup(popup_3f5cd10cae7055be3110f3dca611f5ef)
#         ;
#
#
#
#
#             var circle_marker_da6a5c0e8bfac89371c3f290c77d38d9 = L.circleMarker(
#                 [-3.7480555555555557, -61.65861111111111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_664b6c010d0394f1a48592cdfb15675c);
#
#
#         var popup_6414cadf8f0c255f65791413e5bf6ecd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea37aeb7256e92ebe902f5e319267737 = $(`&lt;div id=&quot;html_ea37aeb7256e92ebe902f5e319267737&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anori&lt;/div&gt;`)[0];
#                 popup_6414cadf8f0c255f65791413e5bf6ecd.setContent(html_ea37aeb7256e92ebe902f5e319267737);
#
#
#
#         circle_marker_da6a5c0e8bfac89371c3f290c77d38d9.bindPopup(popup_6414cadf8f0c255f65791413e5bf6ecd)
#         ;
#
#
#
#
#             var circle_marker_b45670483e3fd23bd81082f7ea36b977 = L.circleMarker(
#                 [-0.9738888888888889, -62.925555555555555],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_664b6c010d0394f1a48592cdfb15675c);
#
#
#         var popup_c11c1efcf3e5e5ec3a55db68070552d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b8139b659b77893b808522cc9f1373e = $(`&lt;div id=&quot;html_1b8139b659b77893b808522cc9f1373e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barcelos&lt;/div&gt;`)[0];
#                 popup_c11c1efcf3e5e5ec3a55db68070552d8.setContent(html_1b8139b659b77893b808522cc9f1373e);
#
#
#
#         circle_marker_b45670483e3fd23bd81082f7ea36b977.bindPopup(popup_c11c1efcf3e5e5ec3a55db68070552d8)
#         ;
#
#
#
#
#             var circle_marker_5b175721536c13f630bc86fc706470d7 = L.circleMarker(
#                 [-3.8983333333333334, -61.37388888888889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor
